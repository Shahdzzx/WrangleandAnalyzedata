# %% [markdown]
# # Data Wrangling Project

# %% [markdown]
# ## Gathering

# %%
import pandas as pd
import numpy as np
import requests

# %%
twitter = pd.read_csv('twitter-archive-enhanced.csv')

# %%
image_source=requests.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv')
with open('image-predictions.tsv', mode ='wb') as file:
    file.write(image_source.content)
    
image = pd.read_csv('image-predictions.tsv', sep='\t' )

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# %%
CONSUMER_KEY = 'Hidden'

CONSUMER_SECRET = 'Hidden'

ACCESS_TOKEN = 'Hidden'

ACCESS_TOKEN_SECRET = 'Hidden'


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth_handler = auth,
                 parser = tweepy.parsers.JSONParser(),
                 wait_on_rate_limit = True,
                 wait_on_rate_limit_notify = True)

# %%
tweet_ids = twitter.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive

count = 0

fails_dict = {}

start = timer()

# Save each tweet's returned JSON as a new line in a .txt file

with open('tweet_json.txt', 'w') as outfile:

# This loop will likely take 20-30 minutes to run because of Twitter's rate limit

    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass

end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Rate limit reached. Sleeping for: 108
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# ...

# %%
selected_attr = []
with open('tweet_json.txt', 'r') as json_file:
    for line in json_file:
        json_data = json.loads(line)
        selected_attr.append({'tweet_id': json_data['id'],
                             'favorites': json_data['favorite_count'],
                             'retweets': json_data['retweet_count'],
                             'timestamp': json_data['created_at']})

# %%
tweet_selected_attr = pd.DataFrame(selected_attr, columns=['tweet_id','favorites','retweets','timestamp'])

tweet_selected_attr.head()
# Out:
#              tweet_id  favorites  retweets                       timestamp
# 0  892420643555336193      36161      7700  Tue Aug 01 16:23:56 +0000 2017
# 1  892177421306343426      31189      5694  Tue Aug 01 00:17:27 +0000 2017
# 2  891815181378084864      23488      3777  Mon Jul 31 00:18:03 +0000 2017
# 3  891689557279858688      39453      7867  Sun Jul 30 15:58:51 +0000 2017
# 4  891327558926688256      37665      8475  Sat Jul 29 16:00:24 +0000 2017

# %% [markdown]
# # Assessing

# %%
twitter
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
image
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
tweet_selected_attr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   2331 non-null   int64
#  1   favorites  2331 non-null   int64
#  2   retweets   2331 non-null   int64
#  3   timestamp  2331 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 73.0+ KB

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
twitter.shape
# Out:
# (2356, 17)

# %%
image.shape
# Out:
# (2075, 12)

# %%
tweet_selected_attr.shape
# Out:
# (2331, 4)

# %%
twitter['rating_numerator'].value_counts()
# Out:
# 12.0      558
# 11.0      464
# 10.0      461
# 13.0      351
# 9.0       158
# 8.0       102
# 7.0        55
# 14.0       54
# 5.0        37
# 6.0        32
# 3.0        19
# 4.0        17
# 1.0         9
# 2.0         9
# 75.0        2
# 15.0        2
# 420.0       2
# 0.0         2
# 144.0       1
# 666.0       1
# 121.0       1
# 182.0       1
# 165.0       1
# 17.0        1
# 45.0        1
# 204.0       1
# 960.0       1
# 1776.0      1
# 84.0        1
# 24.0        1
# 27.0        1
# 88.0        1
# 99.0        1
# 50.0        1
# 80.0        1
# 60.0        1
# 44.0        1
# 20.0        1
# 26.0        1
# 143.0       1
# Name: rating_numerator, dtype: int64

# %%
twitter['name'].value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Cooper       11
# Lucy         11
#            ...
# Vinscent      1
# Suki          1
# Devón         1
# Napolean      1
# Rambo         1
# Name: name, Length: 957, dtype: int64

# %%
len(twitter.loc[(twitter['doggo']== 'None') & (twitter['floofer']== 'None') 
                & (twitter['pupper']== 'None') & (twitter['puppo']== 'None')])
# Out:
# 1976

# %%
sum(twitter.duplicated())
# Out:
# 0

# %%
sum(image.duplicated())
# Out:
# 0

# %%
sum(tweet_selected_attr.duplicated())
# Out:
# 0

# %% [markdown]
# #### Quality
#
# - There are rows that includs retweets and replays and they are not original tweets written by the WeRateDogs account.
# - Some columns have many missing values and they are not required for the analysis.
# - Tweet_id should be object.
# - Rating numerator is int and it should be float.
# - Some ratings take only the decimal value.
# - In tweet ID 740373189193256964, 722974582966214656,  716439118184652801 it takes the first numerator and denominator but they are for dates and other purposes but not for rating.
# - most of the numerator ratings fell in between 1-15 only 15 tweets are above 15.
# - Missing values in the dog stage column.
# - Multiple stages for one row.

# %% [markdown]
# #### Tidiness
# - rating numerators and denominators are in seperate columns.
# - Dog stages are separated in diffrent columns and it sould be under one column.
# - First dog breed prediction should be extracted in a new column.
# - Merging the three datasets in one table.

# %% [markdown]
# ## Cleaning

# %%
twitter_clean = twitter.copy()
tweet_selected_attr_clean = tweet_selected_attr.copy()
image_clean = image.copy()

# %% [markdown]
# ### Quality issue 1

# %% [markdown]
# #### Define

# %% [markdown]
# drop rows that are retweets and replays using is.null

# %% [markdown]
# #### Code

# %%
twitter_clean = twitter_clean[twitter_clean.retweeted_status_id.isnull()]
twitter_clean = twitter_clean[twitter_clean.in_reply_to_user_id.isnull()]

# %% [markdown]
# #### Test

# %%
twitter_clean.shape
# Out:
# (2097, 17)

# %% [markdown]
# ### Quality issue 2

# %% [markdown]
# #### Define

# %% [markdown]
# drop unneeded columns

# %% [markdown]
# #### Code

# %%
twitter_clean.drop(['retweeted_status_timestamp','retweeted_status_id','retweeted_status_user_id','in_reply_to_status_id','in_reply_to_user_id'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ### Quality issue 3

# %% [markdown]
# #### Define

# %% [markdown]
# Change dtype of the tweet_id to object

# %% [markdown]
# #### Code

# %%
twitter_clean.tweet_id = twitter_clean.tweet_id.astype(object)
tweet_selected_attr_clean.tweet_id = tweet_selected_attr_clean.tweet_id.astype(object)
image_clean.tweet_id = image_clean.tweet_id.astype(object)

# %% [markdown]
# # Test

# %%
twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   object
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Quality issue 4

# %% [markdown]
# #### Define

# %% [markdown]
# convert ratings from int to float

# %% [markdown]
# #### Code

# %%
twitter_clean.rating_numerator = twitter_clean.rating_numerator.astype(float)
twitter_clean.rating_denominator = twitter_clean.rating_denominator.astype(float)

# %% [markdown]
# #### Test

# %%
twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   object
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   float64
#  6   rating_denominator  2097 non-null   float64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Quality issue 5

# %% [markdown]
# #### Define

# %% [markdown]
# Extract the decimal values using regex

# %% [markdown]
# #### Code

# %%
twitter_clean[twitter_clean.text.str.contains(r"(\d+\.\d*\/\d+)")][['text','rating_numerator']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                                                                                                                         text  \
# 45  This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
#
#     rating_numerator
# 45               5.0

# %%
# Extract the decimal values using regex
ratings = twitter_clean.text.str.extract('((?:\d+\.)?\d+)\/(\d+)', expand=True)
twitter_clean.rating_numerator = ratings
# Test
twitter_clean[twitter_clean.text.str.contains(r"(\d+\.\d*\/\d+)")][['text','rating_numerator']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                                                                                                                         text  \
# 45  This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
#
#    rating_numerator
# 45             13.5

# %% [markdown]
# #### Test

# %%
twitter_clean[twitter_clean.text.str.contains(r"(\d+\.\d*\/\d+)")][['text','rating_numerator']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                                                                                                                         text  \
# 45  This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
#
#    rating_numerator
# 45             13.5

# %% [markdown]
# ### Quality issue 6

# %% [markdown]
# #### Define

# %% [markdown]
# correct wrong rating values manually for specific tweet_ids that should take the second number in tweet which implies rating

# %% [markdown]
# #### Code & Test

# %%
twitter_clean.loc[1068,'rating_numerator'] = 14
# Test
twitter_clean.loc[1068]
# Out:
# tweet_id                                                                                                                                                                                                                                                           740373189193256964
# timestamp                                                                                                                                                                                                                                                   2016-06-08 02:41:38 +0000
# source                                                                                                                                                                                             <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
twitter_clean.loc[1165,'rating_numerator'] = 13
# Test
twitter_clean.loc[1165]
# Out:
# tweet_id                                                                              722974582966214656
# timestamp                                                                      2016-04-21 02:25:47 +0000
# source                <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# text                                    Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a
# expanded_urls                            https://twitter.com/dog_rates/status/722974582966214656/photo/1
# rating_numerator                                                                                      13
# rating_denominator                                                                                    20
# name                                                                                                None
# doggo                                                                                               None
# ...

# %%
twitter_clean.loc[1202,'rating_numerator'] = 11
# Test
twitter_clean.loc[1202]
# Out:
# tweet_id                                                                                                                 716439118184652801
# timestamp                                                                                                         2016-04-03 01:36:11 +0000
# source                                                   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# text                  This is Bluebert. He just saw that both #FinalFur match ups are split 50/50. Amazed af. 11/10 https://t.co/Kky1DPG4iq
# expanded_urls                                                               https://twitter.com/dog_rates/status/716439118184652801/photo/1
# rating_numerator                                                                                                                         11
# rating_denominator                                                                                                                       50
# ...

# %% [markdown]
# ### Quality issue 7

# %% [markdown]
# #### Define

# %% [markdown]
# Drop the rows that has a rating_numerator higher than 15

# %% [markdown]
# #### Code

# %%
high_rating = twitter_clean[twitter_clean['rating_numerator'] >= 15.00].index

twitter_clean.drop(high_rating, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_clean['rating_numerator'].value_counts()
# Out:
# 12.0    486
# 10.0    436
# 11.0    413
# 13.0    287
# 9.0     153
# 8.0      98
# 7.0      52
# 14.0     38
# 5.0      34
# 6.0      32
# 3.0      19
# 4.0      16
# 2.0       9
# 1.0       5
# 0.0       1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# ### Tidiness issue 1

# %% [markdown]
# #### Define

# %% [markdown]
# Merge numerator and denominator in one table named rating

# %% [markdown]
# #### Code

# %%
twitter_clean['rating'] = twitter_clean['rating_numerator'].astype(str) + "/" + twitter_clean['rating_denominator'].astype(str)

# %% [markdown]
# #### Test

# %%
twitter_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ### Tidiness issue 2

# %% [markdown]
# #### Define

# %% [markdown]
# Merge the dos stages columns in one column

# %% [markdown]
# #### Code

# %%
# Replace None
twitter_clean.doggo.replace('None', '', inplace=True)
twitter_clean.floofer.replace('None', '', inplace=True)
twitter_clean.pupper.replace('None', '', inplace=True)
twitter_clean.puppo.replace('None', '', inplace=True)


twitter_clean['dog_stage'] = twitter_clean.doggo + twitter_clean.floofer + twitter_clean.pupper + twitter_clean.puppo

twitter_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ### Quality issue  8&9

# %% [markdown]
# #### Defina

# %% [markdown]
# Handle multiple stages and missing

# %% [markdown]
# #### Code

# %%
# handle multiple stages

twitter_clean.loc[twitter_clean.dog_stage == 'doggopupper', 'dog_stage'] = 'doggo, pupper'
twitter_clean.loc[twitter_clean.dog_stage == 'doggopuppo', 'dog_stage'] = 'doggo, puppo'
twitter_clean.loc[twitter_clean.dog_stage == 'doggofloofer', 'dog_stage'] = 'doggo, floofer'

# handle missing values
twitter_clean.loc[twitter_clean.dog_stage == '', 'dog_stage'] = np.nan

# %% [markdown]
# #### Test

# %%
twitter_clean.sample()
# Out:
#                 tweet_id                  timestamp  \
# 1037  744709971296780288  2016-06-20 01:54:27 +0000
#
#                                                                                   source  \
# 1037  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                          text  \
# 1037  This is Harvey. He's stealthy af. 10/10 would do my best to pet https://t.co/zAzaRT6NnT
#
#                                                         expanded_urls  \
# 1037  https://twitter.com/dog_rates/status/744709971296780288/photo/1
#
#      rating_numerator  rating_denominator    name dog_stage
# 1037               10                10.0  Harvey       NaN

# %% [markdown]
# ### Tidiness issue 3

# %% [markdown]
# #### Define

# %% [markdown]
# extract the first dog breed prediction

# %% [markdown]
# #### Code

# %%
breed=[]
for i in range(0, len(image_clean)):
    if image_clean['p1_dog'].loc[i, ]:
        breed_type=image_clean['p1'].loc[i, ]
    elif image_clean['p2_dog'].loc[i, ]:
        breed_type=image_clean['p2'].loc[i, ]
    elif image_clean['p3_dog'].loc[i, ]:
        breed_type=image_clean['p3'].loc[i, ]
    else:
        breed_type=np.NaN
    breed.append(breed_type)

# %%
image_clean['dominant_breed']= pd.DataFrame(breed)

# %% [markdown]
# #### Test

# %%
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog  \
# ...

# %% [markdown]
# ### Tideness issue 4

# %% [markdown]
# #### Define

# %% [markdown]
# merging the three datasets in one table

# %% [markdown]
# #### Code

# %%
df_temp_clean = pd.merge(twitter_clean, tweet_selected_attr_clean, on='tweet_id', how='inner')
twitter_master_clean = pd.merge(df_temp_clean, image_clean, on='tweet_id', how='inner')

# %% [markdown]
# #### Test

# %%
twitter_master_clean.head()
# Out:
#              tweet_id                timestamp_x  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ## Storing

# %%
twitter_master_clean.to_csv('twitter_archive_master.csv', index=False)

# %%
df = pd.read_csv('twitter_archive_master.csv')
df.head()
# Out:
#              tweet_id                timestamp_x  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %%
df = pd.read_csv('twitter_archive_master.csv',
                             dtype={'tweet_id':str, 'img_num':int},
                             parse_dates=['timestamp_x'],
                             infer_datetime_format=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1946 non-null   object
#  1   timestamp_x         1946 non-null   datetime64[ns]
#  2   source              1946 non-null   object
#  3   text                1946 non-null   object
#  4   expanded_urls       1946 non-null   object
#  5   rating_numerator    1946 non-null   float64
#  6   rating_denominator  1946 non-null   float64
#  7   name                1946 non-null   object
#  8   dog_stage           301 non-null    object
#  9   rating              1946 non-null   object
#  10  favorites           1946 non-null   int64
#  11  retweets            1946 non-null   int64
#  12  timestamp_y         1946 non-null   object
#  13  jpg_url             1946 non-null   object
#  14  img_num             1946 non-null   int64
# ...

# %% [markdown]
# ## Analyzing & Visualizing Data

# %% [markdown]
# ### Most 5 retweeted and favorited tweets

# %%
## Set column width to infinite 
pd.set_option('display.max_colwidth', None)

# %%
#most 5 retweeted tweets
retweeted = df.sort_values('retweets', ascending = False)
most_retweeted = retweeted.loc[:,['text','retweets']]
most_retweeted.head(5)
# Out:
#                                                                                                                                            text  \
# 757                         Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4
# 792  Here's a doggo blowing bubbles. It's downright legendary. 13/10 would watch on repeat forever (vid by Kent Duryee) https://t.co/YcXgHfp1EC
# 391                                                       This is Stephan. He just wants to help. 13/10 such a good boy https://t.co/DkBYaCAg2d
# 302                             Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
# 58                                   This is Duddles. He did an attempt. 13/10 someone help him (vid by Georgia Felici) https://t.co/UDT7ZkcTgY
#
#      retweets
# 757     77724
# 792     57644
# 391     56663
# 302     43791
# 58      40578

# %%
#most 5 favorited tweets
favorited = df.sort_values('favorites', ascending = False)
most_favorited = favorited.loc[:,['text','favorites']]
most_favorited.head(5)
# Out:
#                                                                                                                                            text  \
# 757                         Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4
# 302                             Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
# 391                                                       This is Stephan. He just wants to help. 13/10 such a good boy https://t.co/DkBYaCAg2d
# 107          This is Jamesy. He gives a kiss to every other pupper he sees on his walk. 13/10 such passion, much tender https://t.co/wk7TfysWHr
# 792  Here's a doggo blowing bubbles. It's downright legendary. 13/10 would watch on repeat forever (vid by Kent Duryee) https://t.co/YcXgHfp1EC
#
#      favorites
# 757     156018
# 302     132902
# 391     120503
# 107     116313
# 792     115232

# %% [markdown]
# ### Most common dog stages in the WeRateDogs twitter account

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df.dog_stage.value_counts()
# Out:
# pupper            200
# doggo              62
# puppo              22
# doggo, pupper       8
# floofer             7
# doggo, puppo        1
# doggo, floofer      1
# Name: dog_stage, dtype: int64

# %%
#plot a bar chart
sc=df['dog_stage'].value_counts().plot(kind='bar', figsize=(8,4), title='Dog stages')
sc.set(xlabel='Dog Stages', ylabel='Count ');

# %% [markdown]
# ### Most common breeds

# %%
bc=sns.countplot(data=df, x='dominant_breed', order=df.dominant_breed.value_counts().iloc[:10].index)
plt.title('Most Common Breeds', size=16)
plt.figure(figsize=(30,80))
bc.set_xticklabels(chart.get_xticklabels(), rotation=45)
bc.set(xlabel='Breed', ylabel='Count ');

plt.savefig('common_breeds.png', bbox_inches='tight');

# %% [markdown]
# ### Most frequent ratings

# %%
df['rating'].value_counts()
# Out:
# 12/10.0      444
# 10/10.0      416
# 11/10.0      392
# 13/10.0      249
# 9/10.0       149
# 8/10.0        95
# 7/10.0        51
# 14/10.0       33
# 6/10.0        32
# 5/10.0        32
# 3/10.0        19
# 4/10.0        15
# 2/10.0         9
# 1/10.0         4
# 9/11.0         1
# 0/10.0         1
# 1/2.0          1
# 4/20.0         1
# 7/11.0         1
# 13.5/10.0      1
# Name: rating, dtype: int64

# %%
rate=df['rating'].value_counts().plot(kind='pie', figsize=(18,12), title='Most frequent ratings');
